# %%
import shutil
from pathlib import Path
import os
import sys
import time

# set the cwd to the parent of the parent of this file

os.chdir(Path(os.getcwd()).parent)

# %%
from env.finger import Finger

from learning.eval_actor import eval_batch_actor

from learning.train_state import TrainConfig, TrainState

from learning.training.train_step import train_step

from nets.nets import (
    StateEncoder,
    ActionEncoder,
    TransitionModel,
    StateDecoder,
    ActionDecoder,
)

import orbax.checkpoint as ocp
import optax

import jax
from jax import numpy as jnp
from jax.experimental.host_callback import id_tap

import wandb

import argparse

# %%
seed = 0

# Generate random key
key = jax.random.PRNGKey(seed)

checkpointer = ocp.PyTreeCheckpointer()

# Save a list of the most recent checkpoints
checkpoint_paths = []
checkpoint_count = 3

# Set up the training config
learning_rate = float(2.5e-4)
every_k = 1

# Set the environment class
env_cls = Finger

# Grab the default environment config from the env class
env_config = env_cls.get_config()

# Set the latent state and action dimensions (here I've just set them the same as the state and action dims)
latent_state_dim = 6
latent_action_dim = 2

# Actually create the training config
train_config = TrainConfig.init(
    learning_rate=learning_rate,
    # Make the optimizer
    optimizer=optax.chain(
        optax.zero_nans(),
        optax.adamw(
            learning_rate=optax.cosine_onecycle_schedule(
                transition_steps=8192,
                peak_value=learning_rate,
                pct_start=0.3,
                div_factor=25.0,
                final_div_factor=1.0,
            ),
        ),
    ),
    # Instantiate all of the networks
    state_encoder=StateEncoder(latent_state_dim=latent_state_dim),
    action_encoder=ActionEncoder(latent_action_dim=latent_action_dim),
    transition_model=TransitionModel(
        latent_state_dim=latent_state_dim, n_layers=8, latent_dim=64, heads=4
    ),
    state_decoder=StateDecoder(state_dim=env_config.state_dim),
    action_decoder=ActionDecoder(act_dim=env_config.act_dim),
    latent_state_dim=latent_state_dim,
    latent_action_dim=latent_action_dim,
    env_config=env_config,
    env_cls=env_cls,
    seed=seed,
    target_net_tau=0.05,
    transition_factor=10.0,
    rollouts=256,
    epochs=64,
    batch_size=64,
    every_k=every_k,
    traj_per_rollout=1024,
    rollout_length=64,
    state_radius=1.6,
    action_radius=2.0,
    reconstruction_weight=1.0,
    forward_weight=1.0,
    smoothness_weight=1.0,
    condensation_weight=1.0,
    dispersion_weight=10.0,
    forward_gate_sharpness=1,
    smoothness_gate_sharpness=1,
    dispersion_gate_sharpness=1,
    condensation_gate_sharpness=1,
    forward_gate_center=-6,
    smoothness_gate_center=-3,
    dispersion_gate_center=-3,
    condensation_gate_center=-6,
)

# Create the train state that contains all of the network and optimizer parameters
rng, key = jax.random.split(key)
train_state = TrainState.init(rng, train_config)

# %%
# Disable wandb
wandb.init(
    mode="disabled",
)
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.

# %% [markdown]
# # Let's just to a sanity check and see if we can train anything at all

# %%
def gen_dat_train_step(train_state, key):
    rng, key = jax.random.split(key)
    state_data = jax.random.normal(
        rng,
        [
            train_state.train_config.batch_size,
            train_state.train_config.rollout_length,
            train_state.train_config.env_config.state_dim,
        ],
    )
    rng, key = jax.random.split(key)
    action_data = jax.random.normal(
        rng,
        [
            train_state.train_config.batch_size,
            train_state.train_config.rollout_length - 1,
            train_state.train_config.env_config.act_dim,
        ],
    )

    train_state = train_step(state_data, action_data, train_state)

    return train_state, None

# %%
rng, key = jax.random.split(key)
rngs = jax.random.split(rng, 16384)
train_state, _ = jax.lax.scan(gen_dat_train_step, train_state, rngs)
# Out:
# Step 0:
# Losses:
# 		state_reconstruction_loss: 0.3926679193973541
# 		action_reconstruction_loss: 0.48948368430137634
#
# Step 1:
# Losses:
# 		state_reconstruction_loss: 0.41215747594833374
# 		action_reconstruction_loss: 0.44861045479774475
#
# Step 2:
# Losses:
# 		state_reconstruction_loss: 0.39103737473487854
# 		action_reconstruction_loss: 0.45167019963264465
#
# Step 3:
# Losses:
# 		state_reconstruction_loss: 0.39208364486694336
# 		action_reconstruction_loss: 0.46379655599594116
#
# Step 4:
# Losses:
# 		state_reconstruction_loss: 0.39477190375328064
# 		action_reconstruction_loss: 0.41120803356170654
#
# Step 5:
# Losses:
# 		state_reconstruction_loss: 0.40082722902297974
# 		action_reconstruction_loss: 0.44826969504356384
#
# Step 6:
# Losses:
# 		state_reconstruction_loss: 0.3656995892524719
# 		action_reconstruction_loss: 0.43818405270576477
#
# Step 7:
# Losses:
# 		state_reconstruction_loss: 0.4132826030254364
# 		action_reconstruction_loss: 0.44849857687950134
#
# Step 8:
# Losses:
# 		state_reconstruction_loss: 0.38991302251815796
# 		action_reconstruction_loss: 0.43427345156669617
#
# Step 9:
# Losses:
# 		state_reconstruction_loss: 0.37784120440483093
# 		action_reconstruction_loss: 0.43931302428245544
#
# Step 10:
# Losses:
# 		state_reconstruction_loss: 0.3914700746536255
# 		action_reconstruction_loss: 0.4954726994037628
#
# Step 11:
# Losses:
# 		state_reconstruction_loss: 0.3782098591327667
# 		action_reconstruction_loss: 0.4587033689022064
#
# Step 12:
# Losses:
# 		state_reconstruction_loss: 0.4071498215198517
# 		action_reconstruction_loss: 0.47746625542640686
#
# Step 13:
# Losses:
# 		state_reconstruction_loss: 0.36895450949668884
# 		action_reconstruction_loss: 0.41892704367637634
#
# Step 14:
# Losses:
# 		state_reconstruction_loss: 0.39254021644592285
# 		action_reconstruction_loss: 0.47093474864959717
#
# Step 15:
# Losses:
# 		state_reconstruction_loss: 0.4342341125011444
# 		action_reconstruction_loss: 0.4439485967159271
#
# Step 16:
# Losses:
# 		state_reconstruction_loss: 0.3950440585613251
# 		action_reconstruction_loss: 0.46322762966156006
#
# Step 17:
# Losses:
# 		state_reconstruction_loss: 0.4253205358982086
# 		action_reconstruction_loss: 0.4183654487133026
#
# Step 18:
# Losses:
# 		state_reconstruction_loss: 0.3913702964782715
# 		action_reconstruction_loss: 0.4079841375350952
#
# Step 19:
# Losses:
# 		state_reconstruction_loss: 0.42452502250671387
# 		action_reconstruction_loss: 0.5123142600059509
#
# Step 20:
# Losses:
# 		state_reconstruction_loss: 0.3844749629497528
# 		action_reconstruction_loss: 0.4954947531223297
#
# Step 21:
# Losses:
# 		state_reconstruction_loss: 0.4138328731060028
# 		action_reconstruction_loss: 0.4936215877532959
#
# Step 22:
# Losses:
# 		state_reconstruction_loss: 0.384611576795578
# 		action_reconstruction_loss: 0.5202003717422485
#
# Step 23:
# Losses:
# 		state_reconstruction_loss: 0.3828485906124115
# 		action_reconstruction_loss: 0.4848269820213318
#
# Step 24:
# Losses:
# 		state_reconstruction_loss: 0.3892352283000946
# 		action_reconstruction_loss: 0.4655284285545349
#
# Step 25:
# Losses:
# 		state_reconstruction_loss: 0.3791293799877167
# 		action_reconstruction_loss: 0.4850841462612152
#
# Step 26:
# Losses:
# 		state_reconstruction_loss: 0.4165785312652588
# 		action_reconstruction_loss: 0.5409913659095764
#
# Step 27:
# Losses:
# 		state_reconstruction_loss: 0.376041054725647
# 		action_reconstruction_loss: 0.44585686922073364
#
# Step 28:
# Losses:
# 		state_reconstruction_loss: 0.4231778681278229
# 		action_reconstruction_loss: 0.444600373506546
#
# Step 29:
# Losses:
# 		state_reconstruction_loss: 0.3867083191871643
# 		action_reconstruction_loss: 0.46817854046821594
#
# Step 30:
# Losses:
# 		state_reconstruction_loss: 0.36818045377731323
# 		action_reconstruction_loss: 0.45731422305107117
#
# Step 31:
# Losses:
# 		state_reconstruction_loss: 0.4050171673297882
# 		action_reconstruction_loss: 0.43080276250839233
#
# Step 32:
# Losses:
# 		state_reconstruction_loss: 0.4188682734966278
# 		action_reconstruction_loss: 0.45926058292388916
#
# Step 33:
# Losses:
# 		state_reconstruction_loss: 0.4045499265193939
# 		action_reconstruction_loss: 0.4678511321544647
#
# Step 34:
# Losses:
# 		state_reconstruction_loss: 0.38399243354797363
# 		action_reconstruction_loss: 0.4521297514438629
#
# Step 35:
# Losses:
# 		state_reconstruction_loss: 0.38043880462646484
# 		action_reconstruction_loss: 0.43448424339294434
#
# Step 36:
# Losses:
# 		state_reconstruction_loss: 0.4048618674278259
# 		action_reconstruction_loss: 0.4548148512840271
#
# Step 37:
# Losses:
# 		state_reconstruction_loss: 0.4086269736289978
# 		action_reconstruction_loss: 0.45763787627220154
#
# Step 38:
# Losses:
# 		state_reconstruction_loss: 0.3853949308395386
# 		action_reconstruction_loss: 0.4938223659992218
#
# Step 39:
# Losses:
# 		state_reconstruction_loss: 0.4010157287120819
# 		action_reconstruction_loss: 0.4409387707710266
#
# Step 40:
# Losses:
# 		state_reconstruction_loss: 0.3979312777519226
# 		action_reconstruction_loss: 0.4556116759777069
#
# Step 41:
# Losses:
# 		state_reconstruction_loss: 0.40688350796699524
# 		action_reconstruction_loss: 0.45772093534469604
#
# Step 42:
# Losses:
# 		state_reconstruction_loss: 0.3733038306236267
# 		action_reconstruction_loss: 0.458745539188385
#
# Step 43:
# Losses:
# 		state_reconstruction_loss: 0.39790213108062744
# 		action_reconstruction_loss: 0.4785057306289673
#
# Step 44:
# Losses:
# 		state_reconstruction_loss: 0.38843458890914917
# 		action_reconstruction_loss: 0.4407423436641693
#
# Step 45:
# Losses:
# 		state_reconstruction_loss: 0.3981126844882965
# 		action_reconstruction_loss: 0.4728255271911621
#
# Step 46:
# Losses:
# 		state_reconstruction_loss: 0.40738341212272644
# 		action_reconstruction_loss: 0.4400995671749115
#
# Step 47:
# Losses:
# 		state_reconstruction_loss: 0.41529443860054016
# 		action_reconstruction_loss: 0.4563789367675781
#
# Step 48:
# Losses:
# 		state_reconstruction_loss: 0.4089791178703308
# 		action_reconstruction_loss: 0.44685855507850647
#
# Step 49:
# Losses:
# 		state_reconstruction_loss: 0.4063725769519806
# 		action_reconstruction_loss: 0.46914246678352356
#
# Step 50:
# Losses:
# 		state_reconstruction_loss: 0.3882811367511749
# 		action_reconstruction_loss: 0.44158580899238586
#
# Step 51:
# Losses:
# 		state_reconstruction_loss: 0.3887079954147339
# 		action_reconstruction_loss: 0.44710567593574524
#
# Step 52:
# Losses:
# 		state_reconstruction_loss: 0.39746972918510437
# 		action_reconstruction_loss: 0.4387238025665283
#
# Step 53:
# Losses:
# 		state_reconstruction_loss: 0.3872315287590027
# 		action_reconstruction_loss: 0.40384283661842346
#
# Step 54:
# Losses:
# 		state_reconstruction_loss: 0.3683850169181824
# 		action_reconstruction_loss: 0.4459133446216583
#
# Step 55:
# Losses:
# 		state_reconstruction_loss: 0.4049224257469177
# 		action_reconstruction_loss: 0.47419363260269165
#
# Step 56:
# Losses:
# 		state_reconstruction_loss: 0.40589702129364014
# 		action_reconstruction_loss: 0.475955069065094
#
# Step 57:
# Losses:
# 		state_reconstruction_loss: 0.41608890891075134
# 		action_reconstruction_loss: 0.4068780541419983
#
# Step 58:
# Losses:
# 		state_reconstruction_loss: 0.3724217414855957
# 		action_reconstruction_loss: 0.4627162516117096
#
# Step 59:
# Losses:
# 		state_reconstruction_loss: 0.39809396862983704
# 		action_reconstruction_loss: 0.4328426420688629
#
# Step 60:
# Losses:
# 		state_reconstruction_loss: 0.3939981758594513
# 		action_reconstruction_loss: 0.42150238156318665
#
# Step 61:
# Losses:
# 		state_reconstruction_loss: 0.40232521295547485
# 		action_reconstruction_loss: 0.47631973028182983
#
# Step 62:
# Losses:
# 		state_reconstruction_loss: 0.40122121572494507
# 		action_reconstruction_loss: 0.4303969740867615
#
# Step 63:
# Losses:
# 		state_reconstruction_loss: 0.40445825457572937
# 		action_reconstruction_loss: 0.41612178087234497
#
# Step 64:
# Losses:
# 		state_reconstruction_loss: 0.3786671757698059
# 		action_reconstruction_loss: 0.44866088032722473
#
# Step 65:
# Losses:
# 		state_reconstruction_loss: 0.42229214310646057
# 		action_reconstruction_loss: 0.4393865764141083
#
# Step 66:
# Losses:
# 		state_reconstruction_loss: 0.40351980924606323
# 		action_reconstruction_loss: 0.4538158178329468
#
# Step 67:
# Losses:
# 		state_reconstruction_loss: 0.41529783606529236
# 		action_reconstruction_loss: 0.3991876244544983
#
# Step 68:
# Losses:
# 		state_reconstruction_loss: 0.40291622281074524
# 		action_reconstruction_loss: 0.43638843297958374
#
# Step 69:
# Losses:
# 		state_reconstruction_loss: 0.45509594678878784
# 		action_reconstruction_loss: 0.40888944268226624
#
# Step 70:
# Losses:
# 		state_reconstruction_loss: 0.39976170659065247
# 		action_reconstruction_loss: 0.4441967308521271
#
# Step 71:
# Losses:
# 		state_reconstruction_loss: 0.38871702551841736
# 		action_reconstruction_loss: 0.44088825583457947
#
# Step 72:
# Losses:
# 		state_reconstruction_loss: 0.385043203830719
# 		action_reconstruction_loss: 0.43449363112449646
#
# Step 73:
# Losses:
# 		state_reconstruction_loss: 0.39737406373023987
# 		action_reconstruction_loss: 0.45477890968322754
#
# Step 74:
# Losses:
# 		state_reconstruction_loss: 0.41940048336982727
# 		action_reconstruction_loss: 0.43100836873054504
#
# Step 75:
# Losses:
# 		state_reconstruction_loss: 0.3734705448150635
# 		action_reconstruction_loss: 0.4353627562522888
#
# Step 76:
# Losses:
# 		state_reconstruction_loss: 0.40019503235816956
# 		action_reconstruction_loss: 0.4102720320224762
#
# Step 77:
# Losses:
# 		state_reconstruction_loss: 0.3809773921966553
# 		action_reconstruction_loss: 0.4363594949245453
#
# Step 78:
# Losses:
# 		state_reconstruction_loss: 0.41481444239616394
# 		action_reconstruction_loss: 0.45800068974494934
#
# Step 79:
# Losses:
# 		state_reconstruction_loss: 0.35748058557510376
# 		action_reconstruction_loss: 0.4689655900001526
#
# Step 80:
# Losses:
# 		state_reconstruction_loss: 0.3789684772491455
# 		action_reconstruction_loss: 0.4329293966293335
#
# Step 81:
# Losses:
# 		state_reconstruction_loss: 0.40450847148895264
# 		action_reconstruction_loss: 0.42485278844833374
#
# Step 82:
# Losses:
# 		state_reconstruction_loss: 0.36614301800727844
# 		action_reconstruction_loss: 0.4333108961582184
#
# Step 83:
# Losses:
# 		state_reconstruction_loss: 0.387216180562973
# 		action_reconstruction_loss: 0.4526692032814026
#
# Step 84:
# Losses:
# 		state_reconstruction_loss: 0.40332138538360596
# 		action_reconstruction_loss: 0.4551900625228882
#
# Step 85:
# Losses:
# 		state_reconstruction_loss: 0.37834182381629944
# 		action_reconstruction_loss: 0.44984468817710876
#
# Step 86:
# Losses:
# 		state_reconstruction_loss: 0.3812673091888428
# 		action_reconstruction_loss: 0.4457547962665558
#
# Step 87:
# Losses:
# 		state_reconstruction_loss: 0.3777279257774353
# 		action_reconstruction_loss: 0.3836948573589325
#
# Step 88:
# Losses:
# 		state_reconstruction_loss: 0.41178202629089355
# 		action_reconstruction_loss: 0.4445345103740692
#
# Step 89:
# Losses:
# 		state_reconstruction_loss: 0.4225572645664215
# 		action_reconstruction_loss: 0.47285348176956177
#
# Step 90:
# Losses:
# 		state_reconstruction_loss: 0.38034701347351074
# 		action_reconstruction_loss: 0.475612610578537
#
# Step 91:
# Losses:
# 		state_reconstruction_loss: 0.3964678943157196
# 		action_reconstruction_loss: 0.4173181354999542
#
# Step 92:
# Losses:
# 		state_reconstruction_loss: 0.39079731702804565
# 		action_reconstruction_loss: 0.4349619746208191
#
# Step 93:
# Losses:
# 		state_reconstruction_loss: 0.3984071612358093
# 		action_reconstruction_loss: 0.4706897437572479
#
# Step 94:
# Losses:
# 		state_reconstruction_loss: 0.39295682311058044
# 		action_reconstruction_loss: 0.4861866533756256
#
# Step 95:
# Losses:
# 		state_reconstruction_loss: 0.3816995322704315
# 		action_reconstruction_loss: 0.43807005882263184
#
# Step 96:
# Losses:
# 		state_reconstruction_loss: 0.42697909474372864
# 		action_reconstruction_loss: 0.47391650080680847
#
# Step 97:
# Losses:
# 		state_reconstruction_loss: 0.3859808146953583
# 		action_reconstruction_loss: 0.45554274320602417
#
# Step 98:
# Losses:
# 		state_reconstruction_loss: 0.4023461639881134
# 		action_reconstruction_loss: 0.47702541947364807
#
# Step 99:
# Losses:
# 		state_reconstruction_loss: 0.381332665681839
# 		action_reconstruction_loss: 0.42188769578933716
#
# Step 100:
# Losses:
# 		state_reconstruction_loss: 0.3964000642299652
# 		action_reconstruction_loss: 0.46097856760025024
#
# Step 101:
# Losses:
# 		state_reconstruction_loss: 0.40976855158805847
# 		action_reconstruction_loss: 0.43898630142211914
#
# Step 102:
# Losses:
# 		state_reconstruction_loss: 0.39216887950897217
# 		action_reconstruction_loss: 0.4400404989719391
#
# Step 103:
# Losses:
# 		state_reconstruction_loss: 0.41418448090553284
# 		action_reconstruction_loss: 0.4732859432697296
#
# Step 104:
# Losses:
# 		state_reconstruction_loss: 0.43027934432029724
# 		action_reconstruction_loss: 0.44439446926116943
#
# Step 105:
# Losses:
# 		state_reconstruction_loss: 0.40634456276893616
# 		action_reconstruction_loss: 0.44659310579299927
#
# Step 106:
# Losses:
# 		state_reconstruction_loss: 0.38032466173171997
# 		action_reconstruction_loss: 0.4090176820755005
#
# Step 107:
# Losses:
# 		state_reconstruction_loss: 0.41380199790000916
# 		action_reconstruction_loss: 0.4832904040813446
#
# Step 108:
# Losses:
# 		state_reconstruction_loss: 0.4097497761249542
# 		action_reconstruction_loss: 0.44159388542175293
#
# Step 109:
# Losses:
# 		state_reconstruction_loss: 0.39665326476097107
# 		action_reconstruction_loss: 0.4658741354942322
#
# Step 110:
# Losses:
# 		state_reconstruction_loss: 0.40257251262664795
# 		action_reconstruction_loss: 0.4766112267971039
#
# Step 111:
# Losses:
# 		state_reconstruction_loss: 0.3942601680755615
# 		action_reconstruction_loss: 0.4983523488044739
#
# Step 112:
# Losses:
# 		state_reconstruction_loss: 0.39275190234184265
# 		action_reconstruction_loss: 0.4872821271419525
#
# Step 113:
# Losses:
# 		state_reconstruction_loss: 0.38504335284233093
# 		action_reconstruction_loss: 0.47445252537727356
#
# Step 114:
# Losses:
# 		state_reconstruction_loss: 0.4058370590209961
# 		action_reconstruction_loss: 0.44735679030418396
#
# Step 115:
# Losses:
# 		state_reconstruction_loss: 0.40773138403892517
# 		action_reconstruction_loss: 0.504607617855072
#
# Step 116:
# Losses:
# 		state_reconstruction_loss: 0.3980622887611389
# 		action_reconstruction_loss: 0.49960342049598694
#
# Step 117:
# Losses:
# 		state_reconstruction_loss: 0.40921124815940857
# 		action_reconstruction_loss: 0.477954238653183
#
# Step 118:
# Losses:
# 		state_reconstruction_loss: 0.40800169110298157
# 		action_reconstruction_loss: 0.4434744417667389
#
# Step 119:
# Losses:
# 		state_reconstruction_loss: 0.4256402850151062
# 		action_reconstruction_loss: 0.5054813623428345
#
# Step 120:
# Losses:
# 		state_reconstruction_loss: 0.3730570077896118
# 		action_reconstruction_loss: 0.5041778087615967
#
# Step 121:
# Losses:
# 		state_reconstruction_loss: 0.41855260729789734
# 		action_reconstruction_loss: 0.5431352853775024
#
# Step 122:
# Losses:
# 		state_reconstruction_loss: 0.40656977891921997
# 		action_reconstruction_loss: 0.5208842158317566
#
# Step 123:
# Losses:
# 		state_reconstruction_loss: 0.4010471701622009
# 		action_reconstruction_loss: 0.4747747480869293
#
# Step 124:
# Losses:
# 		state_reconstruction_loss: 0.40017813444137573
# 		action_reconstruction_loss: 0.4884086847305298
#
# Step 125:
# Losses:
# 		state_reconstruction_loss: 0.41843223571777344
# 		action_reconstruction_loss: 0.4593692421913147
#
# Step 126:
# Losses:
# 		state_reconstruction_loss: 0.38710126280784607
# 		action_reconstruction_loss: 0.47228479385375977
#
# Step 127:
# Losses:
# 		state_reconstruction_loss: 0.42575305700302124
# 		action_reconstruction_loss: 0.498422235250473
#
# Step 128:
# Losses:
# 		state_reconstruction_loss: 0.4288676977157593
# 		action_reconstruction_loss: 0.4832886755466461
#
# Step 129:
# Losses:
# 		state_reconstruction_loss: 0.42320775985717773
# 		action_reconstruction_loss: 0.5087180137634277
#
# Step 130:
# Losses:
# 		state_reconstruction_loss: 0.4099614918231964
# 		action_reconstruction_loss: 0.505717396736145
#
# Step 131:
# Losses:
# 		state_reconstruction_loss: 0.39852097630500793
# 		action_reconstruction_loss: 0.48820486664772034
#
# Step 132:
# Losses:
# 		state_reconstruction_loss: 0.40210282802581787
# 		action_reconstruction_loss: 0.4974912703037262
#
# Step 133:
# Losses:
# 		state_reconstruction_loss: 0.40706509351730347
# 		action_reconstruction_loss: 0.48009854555130005
#
# Step 134:
# Losses:
# 		state_reconstruction_loss: 0.42139291763305664
# 		action_reconstruction_loss: 0.500173807144165
#
# Step 135:
# Losses:
# 		state_reconstruction_loss: 0.398594468832016
# 		action_reconstruction_loss: 0.47244226932525635
#
# Step 136:
# Losses:
# 		state_reconstruction_loss: 0.4198342561721802
# 		action_reconstruction_loss: 0.4650284945964813
#
# Step 137:
# Losses:
# 		state_reconstruction_loss: 0.4080592393875122
# 		action_reconstruction_loss: 0.5238497257232666
#
# Step 138:
# Losses:
# 		state_reconstruction_loss: 0.43354812264442444
# 		action_reconstruction_loss: 0.4851888418197632
#
# Step 139:
# Losses:
# 		state_reconstruction_loss: 0.4267195761203766
# 		action_reconstruction_loss: 0.48989206552505493
#
# Step 140:
# Losses:
# 		state_reconstruction_loss: 0.4100690484046936
# 		action_reconstruction_loss: 0.5168847441673279
#
# Step 141:
# Losses:
# 		state_reconstruction_loss: 0.42634153366088867
# 		action_reconstruction_loss: 0.4953114092350006
#
# Step 142:
# Losses:
# 		state_reconstruction_loss: 0.4325883090496063
# 		action_reconstruction_loss: 0.5079782009124756
#
# Step 143:
# Losses:
# 		state_reconstruction_loss: 0.40096163749694824
# 		action_reconstruction_loss: 0.48166435956954956
#
# Step 144:
# Losses:
# 		state_reconstruction_loss: 0.4181312620639801
# 		action_reconstruction_loss: 0.5327937006950378
#
# Step 145:
# Losses:
# 		state_reconstruction_loss: 0.3901955485343933
# 		action_reconstruction_loss: 0.4526938498020172
#
# Step 146:
# Losses:
# 		state_reconstruction_loss: 0.40502291917800903
# 		action_reconstruction_loss: 0.5665531754493713
#
# Step 147:
# Losses:
# 		state_reconstruction_loss: 0.42545461654663086
# 		action_reconstruction_loss: 0.509055495262146
#
# Step 148:
# Losses:
# 		state_reconstruction_loss: 0.40954458713531494
# 		action_reconstruction_loss: 0.4693959355354309
#
# Step 149:
# Losses:
# 		state_reconstruction_loss: 0.3899111747741699
# 		action_reconstruction_loss: 0.5302117466926575
#
# Step 150:
# Losses:
# 		state_reconstruction_loss: 0.4202609360218048
# 		action_reconstruction_loss: 0.5023446083068848
#
# Step 151:
# Losses:
# 		state_reconstruction_loss: 0.42213037610054016
# 		action_reconstruction_loss: 0.4913340210914612
#
# Step 152:
# Losses:
# 		state_reconstruction_loss: 0.41002294421195984
# 		action_reconstruction_loss: 0.4634960889816284
#
# Step 153:
# Losses:
# 		state_reconstruction_loss: 0.4121403098106384
# 		action_reconstruction_loss: 0.45750871300697327
#
# Step 154:
# Losses:
# 		state_reconstruction_loss: 0.4029133915901184
# 		action_reconstruction_loss: 0.4545302391052246
#
# Step 155:
# Losses:
# 		state_reconstruction_loss: 0.41239240765571594
# 		action_reconstruction_loss: 0.5192112326622009
#
# Step 156:
# Losses:
# 		state_reconstruction_loss: 0.41098618507385254
# 		action_reconstruction_loss: 0.4943436086177826
#
# Step 157:
# Losses:
# 		state_reconstruction_loss: 0.4126265347003937
# 		action_reconstruction_loss: 0.5249281525611877
#
# Step 158:
# Losses:
# 		state_reconstruction_loss: 0.4030906856060028
# 		action_reconstruction_loss: 0.5486429929733276
#
# Step 159:
# Losses:
# 		state_reconstruction_loss: 0.4370500445365906
# 		action_reconstruction_loss: 0.5186946988105774
#
# Step 160:
# Losses:
# 		state_reconstruction_loss: 0.4212583899497986
# 		action_reconstruction_loss: 0.5177950263023376
#
# Step 161:
# Losses:
# 		state_reconstruction_loss: 0.3951095640659332
# 		action_reconstruction_loss: 0.5520006418228149
#
# Step 162:
# Losses:
# 		state_reconstruction_loss: 0.40935978293418884
# 		action_reconstruction_loss: 0.5456107258796692
#
# Step 163:
# Losses:
# 		state_reconstruction_loss: 0.4145980775356293
# 		action_reconstruction_loss: 0.5570862293243408
#
# Step 164:
# Losses:
# 		state_reconstruction_loss: 0.39892205595970154
# 		action_reconstruction_loss: 0.5177291035652161
#
# Step 165:
# Losses:
# 		state_reconstruction_loss: 0.3986159563064575
# 		action_reconstruction_loss: 0.5539671182632446
#
# Step 166:
# Losses:
# 		state_reconstruction_loss: 0.4064507484436035
# 		action_reconstruction_loss: 0.5596810579299927
#
# Step 167:
# Losses:
# 		state_reconstruction_loss: 0.41124117374420166
# 		action_reconstruction_loss: 0.5368555784225464
#
# Step 168:
# Losses:
# 		state_reconstruction_loss: 0.41836458444595337
# 		action_reconstruction_loss: 0.5030911564826965
#
# Step 169:
# Losses:
# 		state_reconstruction_loss: 0.4164295792579651
# 		action_reconstruction_loss: 0.49892792105674744
#
# Step 170:
# Losses:
# 		state_reconstruction_loss: 0.41027575731277466
# 		action_reconstruction_loss: 0.5157229900360107
#
# Step 171:
# Losses:
# 		state_reconstruction_loss: 0.39554300904273987
# 		action_reconstruction_loss: 0.45409780740737915
#
# Step 172:
# Losses:
# 		state_reconstruction_loss: 0.41167861223220825
# 		action_reconstruction_loss: 0.5160004496574402
#
# Step 173:
# Losses:
# 		state_reconstruction_loss: 0.4270090162754059
# 		action_reconstruction_loss: 0.5029900074005127
#
# Step 174:
# Losses:
# 		state_reconstruction_loss: 0.4054746627807617
# 		action_reconstruction_loss: 0.5266291499137878
#
# Step 175:
# Losses:
# 		state_reconstruction_loss: 0.4202049970626831
# 		action_reconstruction_loss: 0.5034219622612
#
# Step 176:
# Losses:
# 		state_reconstruction_loss: 0.4206793010234833
# 		action_reconstruction_loss: 0.5016865134239197
#
# Step 177:
# Losses:
# 		state_reconstruction_loss: 0.41676491498947144
# 		action_reconstruction_loss: 0.5106102228164673
#
# Step 178:
# Losses:
# 		state_reconstruction_loss: 0.3776915967464447
# 		action_reconstruction_loss: 0.48665985465049744
#
# Step 179:
# Losses:
# 		state_reconstruction_loss: 0.4181119501590729
# 		action_reconstruction_loss: 0.4841700792312622
#
# Step 180:
# Losses:
# 		state_reconstruction_loss: 0.41274183988571167
# 		action_reconstruction_loss: 0.48345085978507996
#
# Step 181:
# Losses:
# 		state_reconstruction_loss: 0.4113585352897644
# 		action_reconstruction_loss: 0.5011812448501587
#
# Step 182:
# Losses:
# 		state_reconstruction_loss: 0.41294988989830017
# 		action_reconstruction_loss: 0.5499187707901001
#
# Step 183:
# Losses:
# 		state_reconstruction_loss: 0.3813050091266632
# 		action_reconstruction_loss: 0.49404457211494446
#
# Step 184:
# Losses:
# 		state_reconstruction_loss: 0.40543654561042786
# 		action_reconstruction_loss: 0.49631136655807495
#
# Step 185:
# Losses:
# 		state_reconstruction_loss: 0.37934768199920654
# 		action_reconstruction_loss: 0.4717033803462982
#
# Step 186:
# Losses:
# 		state_reconstruction_loss: 0.38336092233657837
# 		action_reconstruction_loss: 0.5088363289833069
#
# Step 187:
# Losses:
# 		state_reconstruction_loss: 0.4185124337673187
# 		action_reconstruction_loss: 0.4703328311443329
#
# Step 188:
# Losses:
# 		state_reconstruction_loss: 0.399254709482193
# 		action_reconstruction_loss: 0.5324580073356628
#
# Step 189:
# Losses:
# 		state_reconstruction_loss: 0.43742451071739197
# 		action_reconstruction_loss: 0.44728028774261475
#
# Step 190:
# Losses:
# 		state_reconstruction_loss: 0.39753204584121704
# 		action_reconstruction_loss: 0.5123328566551208
#
# Step 191:
# Losses:
# 		state_reconstruction_loss: 0.3886977732181549
# 		action_reconstruction_loss: 0.5149321556091309
#
# Step 192:
# Losses:
# 		state_reconstruction_loss: 0.38677266240119934
# 		action_reconstruction_loss: 0.530733048915863
#
# Step 193:
# Losses:
# 		state_reconstruction_loss: 0.39390408992767334
# 		action_reconstruction_loss: 0.5730851292610168
#
# Step 194:
# Losses:
# 		state_reconstruction_loss: 0.38850346207618713
# 		action_reconstruction_loss: 0.5290777683258057
#
# Step 195:
# Losses:
# 		state_reconstruction_loss: 0.40082302689552307
# 		action_reconstruction_loss: 0.5200246572494507
#
# Step 196:
# Losses:
# 		state_reconstruction_loss: 0.4134179353713989
# 		action_reconstruction_loss: 0.5337713360786438
#
# Step 197:
# Losses:
# 		state_reconstruction_loss: 0.4007209837436676
# 		action_reconstruction_loss: 0.5325179696083069
#
# Step 198:
# Losses:
# 		state_reconstruction_loss: 0.38623878359794617
# 		action_reconstruction_loss: 0.5412236452102661
#
# Step 199:
# Losses:
# 		state_reconstruction_loss: 0.39410069584846497
# 		action_reconstruction_loss: 0.5513259768486023
#
# Step 200:
# Losses:
# 		state_reconstruction_loss: 0.3963625431060791
# 		action_reconstruction_loss: 0.5491621494293213
#
# Step 201:
# Losses:
# 		state_reconstruction_loss: 0.39407286047935486
# 		action_reconstruction_loss: 0.5882703065872192
#
# Step 202:
# Losses:
# 		state_reconstruction_loss: 0.4222378432750702
# 		action_reconstruction_loss: 0.501187801361084
#
# Step 203:
# Losses:
# 		state_reconstruction_loss: 0.38192760944366455
# 		action_reconstruction_loss: 0.547942578792572
#
# Step 204:
# Losses:
# 		state_reconstruction_loss: 0.4327751398086548
# 		action_reconstruction_loss: 0.5502030253410339
#
# Step 205:
# Losses:
# 		state_reconstruction_loss: 0.4030950367450714
# 		action_reconstruction_loss: 0.5688825249671936
#
# Step 206:
# Losses:
# 		state_reconstruction_loss: 0.40083473920822144
# 		action_reconstruction_loss: 0.5664158463478088
#
# Step 207:
# Losses:
# 		state_reconstruction_loss: 0.38859057426452637
# 		action_reconstruction_loss: 0.5362677574157715
#
# Step 208:
# Losses:
# 		state_reconstruction_loss: 0.41107580065727234
# 		action_reconstruction_loss: 0.5376279950141907
#
# Step 209:
# Losses:
# 		state_reconstruction_loss: 0.4100382924079895
# 		action_reconstruction_loss: 0.5551432371139526
#
# Step 210:
# Losses:
# 		state_reconstruction_loss: 0.4065672755241394
# 		action_reconstruction_loss: 0.5290219783782959
#
# Step 211:
# Losses:
# 		state_reconstruction_loss: 0.3842698633670807
# 		action_reconstruction_loss: 0.5577133297920227
#
# Step 212:
# Losses:
# 		state_reconstruction_loss: 0.40863120555877686
# 		action_reconstruction_loss: 0.5342649817466736
#
# Step 213:
# Losses:
# 		state_reconstruction_loss: 0.43392056226730347
# 		action_reconstruction_loss: 0.5024749040603638
#
# Step 214:
# Losses:
# 		state_reconstruction_loss: 0.3938255310058594
# 		action_reconstruction_loss: 0.557157576084137
#
# Step 215:
# Losses:
# 		state_reconstruction_loss: 0.41253507137298584
# 		action_reconstruction_loss: 0.4974544644355774
#
# Step 216:
# Losses:
# 		state_reconstruction_loss: 0.3851701319217682
# 		action_reconstruction_loss: 0.47212615609169006
#
# Step 217:
# Losses:
# 		state_reconstruction_loss: 0.40034031867980957
# 		action_reconstruction_loss: 0.5318742990493774
#
# Step 218:
# Losses:
# 		state_reconstruction_loss: 0.3989222049713135
# 		action_reconstruction_loss: 0.5404274463653564
#
# Step 219:
# Losses:
# 		state_reconstruction_loss: 0.3796926736831665
# 		action_reconstruction_loss: 0.5065291523933411
#
# Step 220:
# Losses:
# 		state_reconstruction_loss: 0.40496864914894104
# 		action_reconstruction_loss: 0.5160099864006042
#
# Step 221:
# Losses:
# 		state_reconstruction_loss: 0.38601547479629517
# 		action_reconstruction_loss: 0.5090835690498352
#
# Step 222:
# Losses:
# 		state_reconstruction_loss: 0.4011201560497284
# 		action_reconstruction_loss: 0.5193180441856384
#
# Step 223:
# Losses:
# 		state_reconstruction_loss: 0.42049482464790344
# 		action_reconstruction_loss: 0.49491509795188904
#
# Step 224:
# Losses:
# 		state_reconstruction_loss: 0.4066641926765442
# 		action_reconstruction_loss: 0.44952690601348877
#
# Step 225:
# Losses:
# 		state_reconstruction_loss: 0.4001983404159546
# 		action_reconstruction_loss: 0.49508124589920044
#
# Step 226:
# Losses:
# 		state_reconstruction_loss: 0.40618252754211426
# 		action_reconstruction_loss: 0.4926294684410095
#
# Step 227:
# Losses:
# 		state_reconstruction_loss: 0.41049695014953613
# 		action_reconstruction_loss: 0.4580688178539276
#
# Step 228:
# Losses:
# 		state_reconstruction_loss: 0.38552334904670715
# 		action_reconstruction_loss: 0.41169142723083496
#
# Step 229:
# Losses:
# 		state_reconstruction_loss: 0.38221287727355957
# 		action_reconstruction_loss: 0.48269104957580566
#
# Step 230:
# Losses:
# 		state_reconstruction_loss: 0.3967883288860321
# 		action_reconstruction_loss: 0.4942101836204529
#
# Step 231:
# Losses:
# 		state_reconstruction_loss: 0.4260229468345642
# 		action_reconstruction_loss: 0.49531498551368713
#
# Step 232:
# Losses:
# 		state_reconstruction_loss: 0.4221575856208801
# 		action_reconstruction_loss: 0.45965105295181274
#
# Step 233:
# Losses:
# 		state_reconstruction_loss: 0.4208742082118988
# 		action_reconstruction_loss: 0.4939810335636139
#
# Step 234:
# Losses:
# 		state_reconstruction_loss: 0.39303556084632874
# 		action_reconstruction_loss: 0.45026102662086487
#
# Step 235:
# Losses:
# 		state_reconstruction_loss: 0.3969976007938385
# 		action_reconstruction_loss: 0.4670892357826233
#
# Step 236:
# Losses:
# 		state_reconstruction_loss: 0.42633968591690063
# 		action_reconstruction_loss: 0.5074859857559204
#
# Step 237:
# Losses:
# 		state_reconstruction_loss: 0.40485262870788574
# 		action_reconstruction_loss: 0.48423120379447937
#
# Step 238:
# Losses:
# 		state_reconstruction_loss: 0.3896956145763397
# 		action_reconstruction_loss: 0.5172566175460815
#
# Step 239:
# Losses:
# 		state_reconstruction_loss: 0.412969172000885
# 		action_reconstruction_loss: 0.5131353735923767
#
# Step 240:
# Losses:
# 		state_reconstruction_loss: 0.388950914144516
# 		action_reconstruction_loss: 0.4694546163082123
#
# Step 241:
# Losses:
# 		state_reconstruction_loss: 0.43118035793304443
# 		action_reconstruction_loss: 0.4346020221710205
#
# Step 242:
# Losses:
# 		state_reconstruction_loss: 0.4243113100528717
# 		action_reconstruction_loss: 0.46626636385917664
#
# Step 243:
# Losses:
# 		state_reconstruction_loss: 0.418807715177536
# 		action_reconstruction_loss: 0.4925963580608368
#
# Step 244:
# Losses:
# 		state_reconstruction_loss: 0.3911338448524475
# 		action_reconstruction_loss: 0.49952712655067444
#
# Step 245:
# Losses:
# 		state_reconstruction_loss: 0.4187796413898468
# 		action_reconstruction_loss: 0.47707271575927734
#
# Step 246:
# Losses:
# 		state_reconstruction_loss: 0.43303990364074707
# 		action_reconstruction_loss: 0.46505680680274963
#
# Step 247:
# Losses:
# 		state_reconstruction_loss: 0.4223637580871582
# 		action_reconstruction_loss: 0.5344634056091309
#
# Step 248:
# Losses:
# 		state_reconstruction_loss: 0.39386966824531555
# 		action_reconstruction_loss: 0.49642977118492126
#
# Step 249:
# Losses:
# 		state_reconstruction_loss: 0.4190206229686737
# 		action_reconstruction_loss: 0.5060369372367859
#
# Step 250:
# Losses:
# 		state_reconstruction_loss: 0.4048396348953247
# 		action_reconstruction_loss: 0.5110635161399841
#
# Step 251:
# Losses:
# 		state_reconstruction_loss: 0.4211724102497101
# 		action_reconstruction_loss: 0.4732716977596283
#
# Step 252:
# Losses:
# 		state_reconstruction_loss: 0.3980300724506378
# 		action_reconstruction_loss: 0.4934191405773163
#
# Step 253:
# Losses:
# 		state_reconstruction_loss: 0.4115059971809387
# 		action_reconstruction_loss: 0.5074774622917175
#
# Step 254:
# Losses:
# 		state_reconstruction_loss: 0.4225209057331085
# 		action_reconstruction_loss: 0.42603597044944763
#
# Step 255:
# Losses:
# 		state_reconstruction_loss: 0.4148237407207489
# 		action_reconstruction_loss: 0.44307011365890503
#
# Step 256:
# Losses:
# 		state_reconstruction_loss: 0.37203535437583923
# 		action_reconstruction_loss: 0.49724677205085754
#
# Step 257:
# Losses:
# 		state_reconstruction_loss: 0.3936695456504822
# 		action_reconstruction_loss: 0.4429093897342682
#
# Step 258:
# Losses:
# 		state_reconstruction_loss: 0.39709705114364624
# 		action_reconstruction_loss: 0.45134344696998596
#
# Step 259:
# Losses:
# 		state_reconstruction_loss: 0.39784982800483704
# 		action_reconstruction_loss: 0.4543848931789398
#
# Step 260:
# Losses:
# 		state_reconstruction_loss: 0.41088077425956726
# 		action_reconstruction_loss: 0.4595770239830017
#
# Step 261:
# Losses:
# 		state_reconstruction_loss: 0.3902505338191986
# 		action_reconstruction_loss: 0.43091535568237305
#
# Step 262:
# Losses:
# 		state_reconstruction_loss: 0.4290025234222412
# 		action_reconstruction_loss: 0.4965876340866089
#
# Step 263:
# Losses:
# 		state_reconstruction_loss: 0.38662588596343994
# 		action_reconstruction_loss: 0.4324907064437866
#
# Step 264:
# Losses:
# 		state_reconstruction_loss: 0.4122750759124756
# 		action_reconstruction_loss: 0.487101674079895
#
# Step 265:
# Losses:
# 		state_reconstruction_loss: 0.3923126459121704
# 		action_reconstruction_loss: 0.4923780858516693
#
# Step 266:
# Losses:
# 		state_reconstruction_loss: 0.38247767090797424
# 		action_reconstruction_loss: 0.4703989624977112
#
# Step 267:
# Losses:
# 		state_reconstruction_loss: 0.39316698908805847
# 		action_reconstruction_loss: 0.5325314998626709
#
# Step 268:
# Losses:
# 		state_reconstruction_loss: 0.3727860450744629
# 		action_reconstruction_loss: 0.4811573624610901
#
# Step 269:
# Losses:
# 		state_reconstruction_loss: 0.4136126637458801
# 		action_reconstruction_loss: 0.5388004183769226
#
# Step 270:
# Losses:
# 		state_reconstruction_loss: 0.39164239168167114
# 		action_reconstruction_loss: 0.49768081307411194
#
# Step 271:
# Losses:
# 		state_reconstruction_loss: 0.38936132192611694
# 		action_reconstruction_loss: 0.5118169784545898
#
# Step 272:
# Losses:
# 		state_reconstruction_loss: 0.401496022939682
# 		action_reconstruction_loss: 0.5503028631210327
#
# Step 273:
# Losses:
# 		state_reconstruction_loss: 0.37877416610717773
# 		action_reconstruction_loss: 0.5027304291725159
#
# Step 274:
# Losses:
# 		state_reconstruction_loss: 0.37590694427490234
# 		action_reconstruction_loss: 0.5015048384666443
#
# Step 275:
# Losses:
# 		state_reconstruction_loss: 0.3758116364479065
# 		action_reconstruction_loss: 0.5010551810264587
#
# Step 276:
# Losses:
# 		state_reconstruction_loss: 0.3793778121471405
# 		action_reconstruction_loss: 0.5343048572540283
#
# Step 277:
# Losses:
# 		state_reconstruction_loss: 0.4165329039096832
# 		action_reconstruction_loss: 0.49061673879623413
#
# Step 278:
# Losses:
# 		state_reconstruction_loss: 0.387820839881897
# 		action_reconstruction_loss: 0.5054470896720886
#
# Step 279:
# Losses:
# 		state_reconstruction_loss: 0.4045126736164093
# 		action_reconstruction_loss: 0.5454195737838745
#
# Step 280:
# Losses:
# 		state_reconstruction_loss: 0.416695773601532
# 		action_reconstruction_loss: 0.5336498022079468
#
# Step 281:
# Losses:
# 		state_reconstruction_loss: 0.3833094835281372
# 		action_reconstruction_loss: 0.49492549896240234
#
# Step 282:
# Losses:
# 		state_reconstruction_loss: 0.3940241038799286
# 		action_reconstruction_loss: 0.5448635220527649
#
# Step 283:
# Losses:
# 		state_reconstruction_loss: 0.4067251980304718
# 		action_reconstruction_loss: 0.5268803238868713
#
# Step 284:
# Losses:
# 		state_reconstruction_loss: 0.3893572986125946
# 		action_reconstruction_loss: 0.5073560476303101
#
# Step 285:
# Losses:
# 		state_reconstruction_loss: 0.4016759693622589
# 		action_reconstruction_loss: 0.47889405488967896
#
# Step 286:
# Losses:
# 		state_reconstruction_loss: 0.4010293781757355
# 		action_reconstruction_loss: 0.5114394426345825
#
# Step 287:
# Losses:
# 		state_reconstruction_loss: 0.38851046562194824
# 		action_reconstruction_loss: 0.4717043936252594
#
# Step 288:
# Losses:
# 		state_reconstruction_loss: 0.4233349859714508
# 		action_reconstruction_loss: 0.4603608548641205
#
# Step 289:
# Losses:
# 		state_reconstruction_loss: 0.40761247277259827
# 		action_reconstruction_loss: 0.47498318552970886
#
# Step 290:
# Losses:
# 		state_reconstruction_loss: 0.4025743901729584
# 		action_reconstruction_loss: 0.4541490077972412
#
# Step 291:
# Losses:
# 		state_reconstruction_loss: 0.4119555652141571
# 		action_reconstruction_loss: 0.4729928970336914
#
# Step 292:
# Losses:
# 		state_reconstruction_loss: 0.4150520861148834
# 		action_reconstruction_loss: 0.5064021944999695
#
# Step 293:
# Losses:
# 		state_reconstruction_loss: 0.42234471440315247
# 		action_reconstruction_loss: 0.4804900884628296
#
# Step 294:
# Losses:
# 		state_reconstruction_loss: 0.4271881878376007
# 		action_reconstruction_loss: 0.41851216554641724
#
# Step 295:
# Losses:
# 		state_reconstruction_loss: 0.4139968454837799
# 		action_reconstruction_loss: 0.51312255859375
#
# Step 296:
# Losses:
# 		state_reconstruction_loss: 0.394204705953598
# 		action_reconstruction_loss: 0.5032241940498352
#
# Step 297:
# Losses:
# 		state_reconstruction_loss: 0.4063277840614319
# 		action_reconstruction_loss: 0.46471619606018066
#
# Step 298:
# Losses:
# 		state_reconstruction_loss: 0.39259281754493713
# 		action_reconstruction_loss: 0.4710218906402588
#
# Step 299:
# Losses:
# 		state_reconstruction_loss: 0.41976112127304077
# 		action_reconstruction_loss: 0.49065443873405457
#
# Step 300:
# Losses:
# 		state_reconstruction_loss: 0.41636019945144653
# 		action_reconstruction_loss: 0.543097972869873
#
# Step 301:
# Losses:
# 		state_reconstruction_loss: 0.4375461935997009
# 		action_reconstruction_loss: 0.4700818657875061
#
# Step 302:
# Losses:
# 		state_reconstruction_loss: 0.4033445119857788
# 		action_reconstruction_loss: 0.4263676404953003
#
# Step 303:
# Losses:
# 		state_reconstruction_loss: 0.41666463017463684
# 		action_reconstruction_loss: 0.49109169840812683
#
# Step 304:
# Losses:
# 		state_reconstruction_loss: 0.40399420261383057
# 		action_reconstruction_loss: 0.45987042784690857
#
# Step 305:
# Losses:
# 		state_reconstruction_loss: 0.43190667033195496
# 		action_reconstruction_loss: 0.508240282535553
#
# Step 306:
# Losses:
# 		state_reconstruction_loss: 0.43043044209480286
# 		action_reconstruction_loss: 0.5115618109703064
#
# Step 307:
# Losses:
# 		state_reconstruction_loss: 0.3954143822193146
# 		action_reconstruction_loss: 0.4745485186576843
#
# Step 308:
# Losses:
# 		state_reconstruction_loss: 0.41128554940223694
# 		action_reconstruction_loss: 0.4625059962272644
#
# Step 309:
# Losses:
# 		state_reconstruction_loss: 0.42122435569763184
# 		action_reconstruction_loss: 0.42497551441192627
#
# Step 310:
# Losses:
# 		state_reconstruction_loss: 0.398015558719635
# 		action_reconstruction_loss: 0.49760136008262634
#
# Step 311:
# Losses:
# 		state_reconstruction_loss: 0.4136764109134674
# 		action_reconstruction_loss: 0.46536701917648315
#
# Step 312:
# Losses:
# 		state_reconstruction_loss: 0.4251484274864197
# 		action_reconstruction_loss: 0.5044621229171753
#
# Step 313:
# Losses:
# 		state_reconstruction_loss: 0.3882014751434326
# 		action_reconstruction_loss: 0.41209760308265686
#
# Step 314:
# Losses:
# 		state_reconstruction_loss: 0.41153204441070557
# 		action_reconstruction_loss: 0.4522857964038849
#
# Step 315:
# Losses:
# 		state_reconstruction_loss: 0.3981778025627136
# 		action_reconstruction_loss: 0.4532575011253357
#
# Step 316:
# Losses:
# 		state_reconstruction_loss: 0.4072648286819458
# 		action_reconstruction_loss: 0.46057936549186707
#
# Step 317:
# Losses:
# 		state_reconstruction_loss: 0.39928874373435974
# 		action_reconstruction_loss: 0.47013089060783386
#
# Step 318:
# Losses:
# 		state_reconstruction_loss: 0.40962156653404236
# 		action_reconstruction_loss: 0.48325979709625244
#
# Step 319:
# Losses:
# 		state_reconstruction_loss: 0.38988927006721497
# 		action_reconstruction_loss: 0.44007039070129395
#
# Step 320:
# Losses:
# 		state_reconstruction_loss: 0.3864859938621521
# 		action_reconstruction_loss: 0.44625622034072876
#
# Step 321:
# Losses:
# 		state_reconstruction_loss: 0.42165112495422363
# 		action_reconstruction_loss: 0.4522233009338379
#
# Step 322:
# Losses:
# 		state_reconstruction_loss: 0.39893025159835815
# 		action_reconstruction_loss: 0.4762325882911682
#
# Step 323:
# Losses:
# 		state_reconstruction_loss: 0.42541393637657166
# 		action_reconstruction_loss: 0.45896798372268677
#
# Step 324:
# Losses:
# 		state_reconstruction_loss: 0.4287712275981903
# 		action_reconstruction_loss: 0.4419158697128296
#
# Step 325:
# Losses:
# 		state_reconstruction_loss: 0.42457571625709534
# 		action_reconstruction_loss: 0.4705767333507538
#
# Step 326:
# Losses:
# 		state_reconstruction_loss: 0.40479621291160583
# 		action_reconstruction_loss: 0.4199524223804474
#
# Step 327:
# Losses:
# 		state_reconstruction_loss: 0.41314518451690674
# 		action_reconstruction_loss: 0.40773096680641174
#
# Step 328:
# Losses:
# 		state_reconstruction_loss: 0.39755353331565857
# 		action_reconstruction_loss: 0.4075109362602234
#
# Step 329:
# Losses:
# 		state_reconstruction_loss: 0.39044633507728577
# 		action_reconstruction_loss: 0.39796313643455505
#
# Step 330:
# Losses:
# 		state_reconstruction_loss: 0.42050835490226746
# 		action_reconstruction_loss: 0.42306575179100037
#
# Step 331:
# Losses:
# 		state_reconstruction_loss: 0.40959227085113525
# 		action_reconstruction_loss: 0.471806138753891
#
# Step 332:
# Losses:
# 		state_reconstruction_loss: 0.38719844818115234
# 		action_reconstruction_loss: 0.4575653374195099
#
# Step 333:
# Losses:
# 		state_reconstruction_loss: 0.4012749493122101
# 		action_reconstruction_loss: 0.48807305097579956
#
# Step 334:
# Losses:
# 		state_reconstruction_loss: 0.3637906312942505
# 		action_reconstruction_loss: 0.4685290455818176
#
# Step 335:
# Losses:
# 		state_reconstruction_loss: 0.3719455301761627
# 		action_reconstruction_loss: 0.4986003637313843
#
# Step 336:
# Losses:
# 		state_reconstruction_loss: 0.40108516812324524
# 		action_reconstruction_loss: 0.4839232265949249
#
# Step 337:
# Losses:
# 		state_reconstruction_loss: 0.4188137948513031
# 		action_reconstruction_loss: 0.5190895199775696
#
# Step 338:
# Losses:
# 		state_reconstruction_loss: 0.3968196511268616
# 		action_reconstruction_loss: 0.5174285173416138
#
# Step 339:
# Losses:
# 		state_reconstruction_loss: 0.39207321405410767
# 		action_reconstruction_loss: 0.477480411529541
#
# Step 340:
# Losses:
# 		state_reconstruction_loss: 0.4010598659515381
# 		action_reconstruction_loss: 0.4729195833206177
#
# Step 341:
# Losses:
# 		state_reconstruction_loss: 0.41223424673080444
# 		action_reconstruction_loss: 0.5276528596878052
#
# Step 342:
# Losses:
# 		state_reconstruction_loss: 0.40735211968421936
# 		action_reconstruction_loss: 0.5950344204902649
#
# Step 343:
# Losses:
# 		state_reconstruction_loss: 0.3760949969291687
# 		action_reconstruction_loss: 0.5204723477363586
#
# Step 344:
# Losses:
# 		state_reconstruction_loss: 0.3856792747974396
# 		action_reconstruction_loss: 0.5713886618614197
#
# Step 345:
# Losses:
# 		state_reconstruction_loss: 0.4021487236022949
# 		action_reconstruction_loss: 0.5480374097824097
#
# Step 346:
# Losses:
# 		state_reconstruction_loss: 0.43035927414894104
# 		action_reconstruction_loss: 0.5607003569602966
#
# Step 347:
# Losses:
# 		state_reconstruction_loss: 0.4366479218006134
# 		action_reconstruction_loss: 0.5817229151725769
#
# Step 348:
# Losses:
# 		state_reconstruction_loss: 0.3923925757408142
# 		action_reconstruction_loss: 0.5495405793190002
#
# Step 349:
# Losses:
# 		state_reconstruction_loss: 0.4026346206665039
# 		action_reconstruction_loss: 0.5995028018951416
#
# Step 350:
# Losses:
# 		state_reconstruction_loss: 0.3832196593284607
# 		action_reconstruction_loss: 0.5823236107826233
#
# Step 351:
# Losses:
# 		state_reconstruction_loss: 0.4114632308483124
# 		action_reconstruction_loss: 0.6203421354293823
#
# Step 352:
# Losses:
# 		state_reconstruction_loss: 0.39813554286956787
# 		action_reconstruction_loss: 0.7163754105567932
#
# Step 353:
# Losses:
# 		state_reconstruction_loss: 0.38496923446655273
# 		action_reconstruction_loss: 0.8038663864135742
#
# Step 354:
# Losses:
# 		state_reconstruction_loss: 0.4029492437839508
# 		action_reconstruction_loss: 0.8066918253898621
#
# Step 355:
# Losses:
# 		state_reconstruction_loss: 0.40214207768440247
# 		action_reconstruction_loss: 0.8690099716186523
#
# Step 356:
# Losses:
# 		state_reconstruction_loss: 0.4040302038192749
# 		action_reconstruction_loss: 0.8542230129241943
#
# Step 357:
# Losses:
# 		state_reconstruction_loss: 0.41018885374069214
# 		action_reconstruction_loss: 0.9495826959609985
#
# Step 358:
# Losses:
# 		state_reconstruction_loss: 0.39590275287628174
# 		action_reconstruction_loss: 0.9646855592727661
#
# Step 359:
# Losses:
# 		state_reconstruction_loss: 0.397411972284317
# 		action_reconstruction_loss: 1.10728120803833
#
# Step 360:
# Losses:
# 		state_reconstruction_loss: 0.42381447553634644
# 		action_reconstruction_loss: 1.1534227132797241
#
# Step 361:
# Losses:
# 		state_reconstruction_loss: 0.40717658400535583
# 		action_reconstruction_loss: 1.1340010166168213
#
# Step 362:
# Losses:
# 		state_reconstruction_loss: 0.389370858669281
# 		action_reconstruction_loss: 1.1819318532943726
#
# Step 363:
# Losses:
# 		state_reconstruction_loss: 0.4093177616596222
# 		action_reconstruction_loss: 1.2189682722091675
#
# Step 364:
# Losses:
# 		state_reconstruction_loss: 0.39675623178482056
# 		action_reconstruction_loss: 1.224883794784546
#
# Step 365:
# Losses:
# 		state_reconstruction_loss: 0.4199984669685364
# 		action_reconstruction_loss: 1.2311006784439087
#
# Step 366:
# Losses:
# 		state_reconstruction_loss: 0.4186329245567322
# 		action_reconstruction_loss: 1.282511830329895
#
# Step 367:
# Losses:
# 		state_reconstruction_loss: 0.43059614300727844
# 		action_reconstruction_loss: 1.3531056642532349
#
# Step 368:
# Losses:
# 		state_reconstruction_loss: 0.4065778851509094
# 		action_reconstruction_loss: 1.3044383525848389
#
# Step 369:
# Losses:
# 		state_reconstruction_loss: 0.41559699177742004
# 		action_reconstruction_loss: 1.3837811946868896
#
# Step 370:
# Losses:
# 		state_reconstruction_loss: 0.4168345332145691
# 		action_reconstruction_loss: 1.3109912872314453
#
# Step 371:
# Losses:
# 		state_reconstruction_loss: 0.3999192714691162
# 		action_reconstruction_loss: 1.394928216934204
#
# Step 372:
# Losses:
# 		state_reconstruction_loss: 0.39313769340515137
# 		action_reconstruction_loss: 1.4166748523712158
#
# Step 373:
# Losses:
# 		state_reconstruction_loss: 0.379594087600708
# 		action_reconstruction_loss: 1.352092981338501
#
# Step 374:
# Losses:
# 		state_reconstruction_loss: 0.3860834836959839
# 		action_reconstruction_loss: 1.3983906507492065
#
# Step 375:
# Losses:
# 		state_reconstruction_loss: 0.3906835913658142
# 		action_reconstruction_loss: 1.3534655570983887
#
# Step 376:
# Losses:
# 		state_reconstruction_loss: 0.40013501048088074
# 		action_reconstruction_loss: 1.391384243965149
#
# Step 377:
# Losses:
# 		state_reconstruction_loss: 0.3974766731262207
# 		action_reconstruction_loss: 1.3793776035308838
#
# Step 378:
# Losses:
# 		state_reconstruction_loss: 0.3783860206604004
# 		action_reconstruction_loss: 1.4494191408157349
#
# Step 379:
# Losses:
# 		state_reconstruction_loss: 0.40725746750831604
# 		action_reconstruction_loss: 1.3495861291885376
#
# Step 380:
# Losses:
# 		state_reconstruction_loss: 0.39677685499191284
# 		action_reconstruction_loss: 1.3837292194366455
#
# Step 381:
# Losses:
# 		state_reconstruction_loss: 0.4144502878189087
# 		action_reconstruction_loss: 1.3420406579971313
#
# Step 382:
# Losses:
# 		state_reconstruction_loss: 0.4194392263889313
# 		action_reconstruction_loss: 1.3686693906784058
#
# Step 383:
# Losses:
# 		state_reconstruction_loss: 0.39765751361846924
# 		action_reconstruction_loss: 1.3199468851089478
#
# Step 384:
# Losses:
# 		state_reconstruction_loss: 0.39538291096687317
# 		action_reconstruction_loss: 1.2225565910339355
#
# Step 385:
# Losses:
# 		state_reconstruction_loss: 0.38684093952178955
# 		action_reconstruction_loss: 1.2338687181472778
#
# Step 386:
# Losses:
# 		state_reconstruction_loss: 0.3689526617527008
# 		action_reconstruction_loss: 1.2909644842147827
#
# Step 387:
# Losses:
# 		state_reconstruction_loss: 0.3976024389266968
# 		action_reconstruction_loss: 1.234084963798523
#
# Step 388:
# Losses:
# 		state_reconstruction_loss: 0.38266271352767944
# 		action_reconstruction_loss: 1.2337441444396973
#
# Step 389:
# Losses:
# 		state_reconstruction_loss: 0.41067391633987427
# 		action_reconstruction_loss: 1.2126431465148926
#
# Step 390:
# Losses:
# 		state_reconstruction_loss: 0.40266749262809753
# 		action_reconstruction_loss: 1.1794284582138062
#
# Step 391:
# Losses:
# 		state_reconstruction_loss: 0.3828994333744049
# 		action_reconstruction_loss: 1.1722928285598755
#
# Step 392:
# Losses:
# 		state_reconstruction_loss: 0.3687148988246918
# 		action_reconstruction_loss: 1.139623999595642
#
# Step 393:
# Losses:
# 		state_reconstruction_loss: 0.40794578194618225
# 		action_reconstruction_loss: 1.1202125549316406
#
# Step 394:
# Losses:
# 		state_reconstruction_loss: 0.3992452025413513
# 		action_reconstruction_loss: 1.1259477138519287
#
# Step 395:
# Losses:
# 		state_reconstruction_loss: 0.39807620644569397
# 		action_reconstruction_loss: 1.1054630279541016
#
# Step 396:
# Losses:
# 		state_reconstruction_loss: 0.39375126361846924
# 		action_reconstruction_loss: 1.1355562210083008
#
# Step 397:
# Losses:
# 		state_reconstruction_loss: 0.38810664415359497
# 		action_reconstruction_loss: 1.0575883388519287
#
# Step 398:
# Losses:
# 		state_reconstruction_loss: 0.4056072235107422
# 		action_reconstruction_loss: 1.1230396032333374
#
# Step 399:
# Losses:
# 		state_reconstruction_loss: 0.4192832410335541
# 		action_reconstruction_loss: 1.1250075101852417
#
# Step 400:
# Losses:
# 		state_reconstruction_loss: 0.38670486211776733
# 		action_reconstruction_loss: 1.0252095460891724
#
# Step 401:
# Losses:
# 		state_reconstruction_loss: 0.3954210579395294
# 		action_reconstruction_loss: 1.0040572881698608
#
# Step 402:
# Losses:
# 		state_reconstruction_loss: 0.38817039132118225
# 		action_reconstruction_loss: 1.0183134078979492
#
# Step 403:
# Losses:
# 		state_reconstruction_loss: 0.38640886545181274
# 		action_reconstruction_loss: 1.0263025760650635
#
# Step 404:
# Losses:
# 		state_reconstruction_loss: 0.39157846570014954
# 		action_reconstruction_loss: 0.9842397570610046
#
# Step 405:
# Losses:
# 		state_reconstruction_loss: 0.380053848028183
# 		action_reconstruction_loss: 0.9974411725997925
#
# Step 406:
# Losses:
# 		state_reconstruction_loss: 0.3827193081378937
# 		action_reconstruction_loss: 0.9144474267959595
#
# Step 407:
# Losses:
# 		state_reconstruction_loss: 0.41346144676208496
# 		action_reconstruction_loss: 0.9423626065254211
#
# Step 408:
# Losses:
# 		state_reconstruction_loss: 0.39133358001708984
# 		action_reconstruction_loss: 0.8850299119949341
#
# Step 409:
# Losses:
# 		state_reconstruction_loss: 0.40389540791511536
# 		action_reconstruction_loss: 0.9468563199043274
#
# Step 410:
# Losses:
# 		state_reconstruction_loss: 0.40774667263031006
# 		action_reconstruction_loss: 0.9054887890815735
#
# Step 411:
# Losses:
# 		state_reconstruction_loss: 0.3569544553756714
# 		action_reconstruction_loss: 0.8639324903488159
#
# Step 412:
# Losses:
# ...
# 		action_reconstruction_loss: 0.42591598629951477
#
# Step 16250:
# Losses:
# 		state_reconstruction_loss: 0.3595692217350006
# 		action_reconstruction_loss: 0.40192392468452454
#
# Step 16251:
# Losses:
# 		state_reconstruction_loss: 0.34815067052841187
# 		action_reconstruction_loss: 0.41615644097328186
#
# Step 16252:
# Losses:
# 		state_reconstruction_loss: 0.35610201954841614
# 		action_reconstruction_loss: 0.40646013617515564
#
# Step 16253:
# Losses:
# 		state_reconstruction_loss: 0.34276682138442993
# 		action_reconstruction_loss: 0.40739667415618896
#
# Step 16254:
# Losses:
# 		state_reconstruction_loss: 0.3366401195526123
# 		action_reconstruction_loss: 0.34958189725875854
#
# Step 16255:
# Losses:
# 		state_reconstruction_loss: 0.370432049036026
# 		action_reconstruction_loss: 0.48610174655914307
#
# Step 16256:
# Losses:
# 		state_reconstruction_loss: 0.3472558856010437
# 		action_reconstruction_loss: 0.38705572485923767
#
# Step 16257:
# Losses:
# 		state_reconstruction_loss: 0.32292428612709045
# 		action_reconstruction_loss: 0.3651311695575714
#
# Step 16258:
# Losses:
# 		state_reconstruction_loss: 0.34214797616004944
# 		action_reconstruction_loss: 0.4345197081565857
#
# Step 16259:
# Losses:
# 		state_reconstruction_loss: 0.3566770553588867
# 		action_reconstruction_loss: 0.38682594895362854
#
# Step 16260:
# Losses:
# 		state_reconstruction_loss: 0.3497221767902374
# 		action_reconstruction_loss: 0.40999341011047363
#
# Step 16261:
# Losses:
# 		state_reconstruction_loss: 0.38585883378982544
# 		action_reconstruction_loss: 0.405268132686615
#
# Step 16262:
# Losses:
# 		state_reconstruction_loss: 0.3473522663116455
# 		action_reconstruction_loss: 0.38545969128608704
#
# Step 16263:
# Losses:
# 		state_reconstruction_loss: 0.3681582808494568
# 		action_reconstruction_loss: 0.4078853130340576
#
# Step 16264:
# Losses:
# 		state_reconstruction_loss: 0.37116527557373047
# 		action_reconstruction_loss: 0.4061402678489685
#
# Step 16265:
# Losses:
# 		state_reconstruction_loss: 0.38117358088493347
# 		action_reconstruction_loss: 0.3958512842655182
#
# Step 16266:
# Losses:
# 		state_reconstruction_loss: 0.3342060148715973
# 		action_reconstruction_loss: 0.3735947608947754
#
# Step 16267:
# Losses:
# 		state_reconstruction_loss: 0.37373802065849304
# 		action_reconstruction_loss: 0.3831592798233032
#
# Step 16268:
# Losses:
# 		state_reconstruction_loss: 0.35580024123191833
# 		action_reconstruction_loss: 0.36872321367263794
#
# Step 16269:
# Losses:
# 		state_reconstruction_loss: 0.3605276048183441
# 		action_reconstruction_loss: 0.37392979860305786
#
# Step 16270:
# Losses:
# 		state_reconstruction_loss: 0.3703800141811371
# 		action_reconstruction_loss: 0.44249558448791504
#
# Step 16271:
# Losses:
# 		state_reconstruction_loss: 0.36180904507637024
# 		action_reconstruction_loss: 0.4421738088130951
#
# Step 16272:
# Losses:
# 		state_reconstruction_loss: 0.37948864698410034
# 		action_reconstruction_loss: 0.41019442677497864
#
# Step 16273:
# Losses:
# 		state_reconstruction_loss: 0.33876505494117737
# 		action_reconstruction_loss: 0.35173624753952026
#
# Step 16274:
# Losses:
# 		state_reconstruction_loss: 0.3682386577129364
# 		action_reconstruction_loss: 0.3922359049320221
#
# Step 16275:
# Losses:
# 		state_reconstruction_loss: 0.34890350699424744
# 		action_reconstruction_loss: 0.42407000064849854
#
# Step 16276:
# Losses:
# 		state_reconstruction_loss: 0.3605046272277832
# 		action_reconstruction_loss: 0.41455817222595215
#
# Step 16277:
# Losses:
# 		state_reconstruction_loss: 0.4007493257522583
# 		action_reconstruction_loss: 0.4385867416858673
#
# Step 16278:
# Losses:
# 		state_reconstruction_loss: 0.3707076609134674
# 		action_reconstruction_loss: 0.35722532868385315
#
# Step 16279:
# Losses:
# 		state_reconstruction_loss: 0.3676544427871704
# 		action_reconstruction_loss: 0.414728581905365
#
# Step 16280:
# Losses:
# 		state_reconstruction_loss: 0.37196049094200134
# 		action_reconstruction_loss: 0.38539767265319824
#
# Step 16281:
# Losses:
# 		state_reconstruction_loss: 0.34337347745895386
# 		action_reconstruction_loss: 0.3949165642261505
#
# Step 16282:
# Losses:
# 		state_reconstruction_loss: 0.3292994797229767
# 		action_reconstruction_loss: 0.36106815934181213
#
# Step 16283:
# Losses:
# 		state_reconstruction_loss: 0.3565364480018616
# 		action_reconstruction_loss: 0.385715514421463
#
# Step 16284:
# Losses:
# 		state_reconstruction_loss: 0.3617307245731354
# 		action_reconstruction_loss: 0.3924563527107239
#
# Step 16285:
# Losses:
# 		state_reconstruction_loss: 0.31385740637779236
# 		action_reconstruction_loss: 0.3913191556930542
#
# Step 16286:
# Losses:
# 		state_reconstruction_loss: 0.37708401679992676
# 		action_reconstruction_loss: 0.4193445146083832
#
# Step 16287:
# Losses:
# 		state_reconstruction_loss: 0.35605114698410034
# 		action_reconstruction_loss: 0.41399991512298584
#
# Step 16288:
# Losses:
# 		state_reconstruction_loss: 0.3591421842575073
# 		action_reconstruction_loss: 0.41397127509117126
#
# Step 16289:
# Losses:
# 		state_reconstruction_loss: 0.3729146122932434
# 		action_reconstruction_loss: 0.4423341751098633
#
# Step 16290:
# Losses:
# 		state_reconstruction_loss: 0.35413751006126404
# 		action_reconstruction_loss: 0.39641639590263367
#
# Step 16291:
# Losses:
# 		state_reconstruction_loss: 0.36892256140708923
# 		action_reconstruction_loss: 0.42855679988861084
#
# Step 16292:
# Losses:
# 		state_reconstruction_loss: 0.38701680302619934
# 		action_reconstruction_loss: 0.37274619936943054
#
# Step 16293:
# Losses:
# 		state_reconstruction_loss: 0.34993085265159607
# 		action_reconstruction_loss: 0.40064942836761475
#
# Step 16294:
# Losses:
# 		state_reconstruction_loss: 0.37204867601394653
# 		action_reconstruction_loss: 0.35060539841651917
#
# Step 16295:
# Losses:
# 		state_reconstruction_loss: 0.37428173422813416
# 		action_reconstruction_loss: 0.41304290294647217
#
# Step 16296:
# Losses:
# 		state_reconstruction_loss: 0.3587309718132019
# 		action_reconstruction_loss: 0.36130914092063904
#
# Step 16297:
# Losses:
# 		state_reconstruction_loss: 0.3738640546798706
# 		action_reconstruction_loss: 0.388859361410141
#
# Step 16298:
# Losses:
# 		state_reconstruction_loss: 0.3434180021286011
# 		action_reconstruction_loss: 0.42922553420066833
#
# Step 16299:
# Losses:
# 		state_reconstruction_loss: 0.38440901041030884
# 		action_reconstruction_loss: 0.3888060748577118
#
# Step 16300:
# Losses:
# 		state_reconstruction_loss: 0.3406734764575958
# 		action_reconstruction_loss: 0.37356895208358765
#
# Step 16301:
# Losses:
# 		state_reconstruction_loss: 0.3597562313079834
# 		action_reconstruction_loss: 0.3726389706134796
#
# Step 16302:
# Losses:
# 		state_reconstruction_loss: 0.3519006371498108
# 		action_reconstruction_loss: 0.3815934658050537
#
# Step 16303:
# Losses:
# 		state_reconstruction_loss: 0.4032762050628662
# 		action_reconstruction_loss: 0.4054231643676758
#
# Step 16304:
# Losses:
# 		state_reconstruction_loss: 0.3641779124736786
# 		action_reconstruction_loss: 0.40781524777412415
#
# Step 16305:
# Losses:
# 		state_reconstruction_loss: 0.35592788457870483
# 		action_reconstruction_loss: 0.43392208218574524
#
# Step 16306:
# Losses:
# 		state_reconstruction_loss: 0.3753834068775177
# 		action_reconstruction_loss: 0.41387197375297546
#
# Step 16307:
# Losses:
# 		state_reconstruction_loss: 0.3729100227355957
# 		action_reconstruction_loss: 0.34212997555732727
#
# Step 16308:
# Losses:
# 		state_reconstruction_loss: 0.3800535202026367
# 		action_reconstruction_loss: 0.38626864552497864
#
# Step 16309:
# Losses:
# 		state_reconstruction_loss: 0.36722874641418457
# 		action_reconstruction_loss: 0.40576884150505066
#
# Step 16310:
# Losses:
# 		state_reconstruction_loss: 0.35522621870040894
# 		action_reconstruction_loss: 0.386692076921463
#
# Step 16311:
# Losses:
# 		state_reconstruction_loss: 0.3532332181930542
# 		action_reconstruction_loss: 0.4012804329395294
#
# Step 16312:
# Losses:
# 		state_reconstruction_loss: 0.37375345826148987
# 		action_reconstruction_loss: 0.43703582882881165
#
# Step 16313:
# Losses:
# 		state_reconstruction_loss: 0.38185906410217285
# 		action_reconstruction_loss: 0.41345566511154175
#
# Step 16314:
# Losses:
# 		state_reconstruction_loss: 0.34128332138061523
# 		action_reconstruction_loss: 0.39296069741249084
#
# Step 16315:
# Losses:
# 		state_reconstruction_loss: 0.37856489419937134
# 		action_reconstruction_loss: 0.3886951506137848
#
# Step 16316:
# Losses:
# 		state_reconstruction_loss: 0.3524933457374573
# 		action_reconstruction_loss: 0.4262646436691284
#
# Step 16317:
# Losses:
# 		state_reconstruction_loss: 0.35538744926452637
# 		action_reconstruction_loss: 0.40752607583999634
#
# Step 16318:
# Losses:
# 		state_reconstruction_loss: 0.32763028144836426
# 		action_reconstruction_loss: 0.46228018403053284
#
# Step 16319:
# Losses:
# 		state_reconstruction_loss: 0.3501602113246918
# 		action_reconstruction_loss: 0.4284979999065399
#
# Step 16320:
# Losses:
# 		state_reconstruction_loss: 0.340083509683609
# 		action_reconstruction_loss: 0.4233001470565796
#
# Step 16321:
# Losses:
# 		state_reconstruction_loss: 0.36391374468803406
# 		action_reconstruction_loss: 0.38706621527671814
#
# Step 16322:
# Losses:
# 		state_reconstruction_loss: 0.35130175948143005
# 		action_reconstruction_loss: 0.38811802864074707
#
# Step 16323:
# Losses:
# 		state_reconstruction_loss: 0.36253437399864197
# 		action_reconstruction_loss: 0.3677438497543335
#
# Step 16324:
# Losses:
# 		state_reconstruction_loss: 0.3596327006816864
# 		action_reconstruction_loss: 0.3457185924053192
#
# Step 16325:
# Losses:
# 		state_reconstruction_loss: 0.36541473865509033
# 		action_reconstruction_loss: 0.3595176041126251
#
# Step 16326:
# Losses:
# 		state_reconstruction_loss: 0.3605133295059204
# 		action_reconstruction_loss: 0.3387742042541504
#
# Step 16327:
# Losses:
# 		state_reconstruction_loss: 0.3581143915653229
# 		action_reconstruction_loss: 0.41098248958587646
#
# Step 16328:
# Losses:
# 		state_reconstruction_loss: 0.3409903645515442
# 		action_reconstruction_loss: 0.40425294637680054
#
# Step 16329:
# Losses:
# 		state_reconstruction_loss: 0.35856691002845764
# 		action_reconstruction_loss: 0.424620658159256
#
# Step 16330:
# Losses:
# 		state_reconstruction_loss: 0.34615564346313477
# 		action_reconstruction_loss: 0.35456252098083496
#
# Step 16331:
# Losses:
# 		state_reconstruction_loss: 0.36342525482177734
# 		action_reconstruction_loss: 0.37807783484458923
#
# Step 16332:
# Losses:
# 		state_reconstruction_loss: 0.35254624485969543
# 		action_reconstruction_loss: 0.3907698690891266
#
# Step 16333:
# Losses:
# 		state_reconstruction_loss: 0.36994320154190063
# 		action_reconstruction_loss: 0.4210289716720581
#
# Step 16334:
# Losses:
# 		state_reconstruction_loss: 0.3378013074398041
# 		action_reconstruction_loss: 0.36848965287208557
#
# Step 16335:
# Losses:
# 		state_reconstruction_loss: 0.3715015947818756
# 		action_reconstruction_loss: 0.36955609917640686
#
# Step 16336:
# Losses:
# 		state_reconstruction_loss: 0.34840601682662964
# 		action_reconstruction_loss: 0.3821442425251007
#
# Step 16337:
# Losses:
# 		state_reconstruction_loss: 0.3807443678379059
# 		action_reconstruction_loss: 0.40264666080474854
#
# Step 16338:
# Losses:
# 		state_reconstruction_loss: 0.36033710837364197
# 		action_reconstruction_loss: 0.4314431846141815
#
# Step 16339:
# Losses:
# 		state_reconstruction_loss: 0.3901650309562683
# 		action_reconstruction_loss: 0.4034421443939209
#
# Step 16340:
# Losses:
# 		state_reconstruction_loss: 0.34532761573791504
# 		action_reconstruction_loss: 0.36954084038734436
#
# Step 16341:
# Losses:
# 		state_reconstruction_loss: 0.34870436787605286
# 		action_reconstruction_loss: 0.34392115473747253
#
# Step 16342:
# Losses:
# 		state_reconstruction_loss: 0.3670060932636261
# 		action_reconstruction_loss: 0.3646700084209442
#
# Step 16343:
# Losses:
# 		state_reconstruction_loss: 0.3741258680820465
# 		action_reconstruction_loss: 0.4246363937854767
#
# Step 16344:
# Losses:
# 		state_reconstruction_loss: 0.3531414866447449
# 		action_reconstruction_loss: 0.42527511715888977
#
# Step 16345:
# Losses:
# 		state_reconstruction_loss: 0.37022116780281067
# 		action_reconstruction_loss: 0.3566981256008148
#
# Step 16346:
# Losses:
# 		state_reconstruction_loss: 0.3594423532485962
# 		action_reconstruction_loss: 0.405682772397995
#
# Step 16347:
# Losses:
# 		state_reconstruction_loss: 0.3854005038738251
# 		action_reconstruction_loss: 0.37760308384895325
#
# Step 16348:
# Losses:
# 		state_reconstruction_loss: 0.3391105830669403
# 		action_reconstruction_loss: 0.402270644903183
#
# Step 16349:
# Losses:
# 		state_reconstruction_loss: 0.3508148789405823
# 		action_reconstruction_loss: 0.45754772424697876
#
# Step 16350:
# Losses:
# 		state_reconstruction_loss: 0.3772294223308563
# 		action_reconstruction_loss: 0.3751167058944702
#
# Step 16351:
# Losses:
# 		state_reconstruction_loss: 0.35950493812561035
# 		action_reconstruction_loss: 0.37206777930259705
#
# Step 16352:
# Losses:
# 		state_reconstruction_loss: 0.358516126871109
# 		action_reconstruction_loss: 0.42012354731559753
#
# Step 16353:
# Losses:
# 		state_reconstruction_loss: 0.3407726287841797
# 		action_reconstruction_loss: 0.4042118191719055
#
# Step 16354:
# Losses:
# 		state_reconstruction_loss: 0.3483142554759979
# 		action_reconstruction_loss: 0.3247482478618622
#
# Step 16355:
# Losses:
# 		state_reconstruction_loss: 0.3551602065563202
# 		action_reconstruction_loss: 0.37274402379989624
#
# Step 16356:
# Losses:
# 		state_reconstruction_loss: 0.3629302382469177
# 		action_reconstruction_loss: 0.3613532781600952
#
# Step 16357:
# Losses:
# 		state_reconstruction_loss: 0.3700040578842163
# 		action_reconstruction_loss: 0.3665814697742462
#
# Step 16358:
# Losses:
# 		state_reconstruction_loss: 0.38101837038993835
# 		action_reconstruction_loss: 0.36571288108825684
#
# Step 16359:
# Losses:
# 		state_reconstruction_loss: 0.3674481511116028
# 		action_reconstruction_loss: 0.36326900124549866
#
# Step 16360:
# Losses:
# 		state_reconstruction_loss: 0.37902718782424927
# 		action_reconstruction_loss: 0.3892381489276886
#
# Step 16361:
# Losses:
# 		state_reconstruction_loss: 0.36765801906585693
# 		action_reconstruction_loss: 0.35297125577926636
#
# Step 16362:
# Losses:
# 		state_reconstruction_loss: 0.33099547028541565
# 		action_reconstruction_loss: 0.3607570230960846
#
# Step 16363:
# Losses:
# 		state_reconstruction_loss: 0.3571721017360687
# 		action_reconstruction_loss: 0.3385893404483795
#
# Step 16364:
# Losses:
# 		state_reconstruction_loss: 0.35165008902549744
# 		action_reconstruction_loss: 0.39227351546287537
#
# Step 16365:
# Losses:
# 		state_reconstruction_loss: 0.3707393407821655
# 		action_reconstruction_loss: 0.35254302620887756
#
# Step 16366:
# Losses:
# 		state_reconstruction_loss: 0.34225353598594666
# 		action_reconstruction_loss: 0.3925059735774994
#
# Step 16367:
# Losses:
# 		state_reconstruction_loss: 0.3525087237358093
# 		action_reconstruction_loss: 0.4443086087703705
#
# Step 16368:
# Losses:
# 		state_reconstruction_loss: 0.3574920892715454
# 		action_reconstruction_loss: 0.41607093811035156
#
# Step 16369:
# Losses:
# 		state_reconstruction_loss: 0.3580563962459564
# 		action_reconstruction_loss: 0.4148588180541992
#
# Step 16370:
# Losses:
# 		state_reconstruction_loss: 0.3653942942619324
# 		action_reconstruction_loss: 0.38022997975349426
#
# Step 16371:
# Losses:
# 		state_reconstruction_loss: 0.3826988935470581
# 		action_reconstruction_loss: 0.40006208419799805
#
# Step 16372:
# Losses:
# 		state_reconstruction_loss: 0.35457897186279297
# 		action_reconstruction_loss: 0.3736014664173126
#
# Step 16373:
# Losses:
# 		state_reconstruction_loss: 0.39456483721733093
# 		action_reconstruction_loss: 0.3741217851638794
#
# Step 16374:
# Losses:
# 		state_reconstruction_loss: 0.35888880491256714
# 		action_reconstruction_loss: 0.376072496175766
#
# Step 16375:
# Losses:
# 		state_reconstruction_loss: 0.3639194369316101
# 		action_reconstruction_loss: 0.31256961822509766
#
# Step 16376:
# Losses:
# 		state_reconstruction_loss: 0.34710973501205444
# 		action_reconstruction_loss: 0.41957423090934753
#
# Step 16377:
# Losses:
# 		state_reconstruction_loss: 0.341171532869339
# 		action_reconstruction_loss: 0.36226633191108704
#
# Step 16378:
# Losses:
# 		state_reconstruction_loss: 0.34319615364074707
# 		action_reconstruction_loss: 0.38628146052360535
#
# Step 16379:
# Losses:
# 		state_reconstruction_loss: 0.36687156558036804
# 		action_reconstruction_loss: 0.33587023615837097
#
# Step 16380:
# Losses:
# 		state_reconstruction_loss: 0.3353848159313202
# 		action_reconstruction_loss: 0.3416036069393158
#
# Step 16381:
# Losses:
# 		state_reconstruction_loss: 0.3503834009170532
# 		action_reconstruction_loss: 0.42763540148735046
#
# Step 16382:
# Losses:
# 		state_reconstruction_loss: 0.34684574604034424
# 		action_reconstruction_loss: 0.3945721387863159
#
# Step 16383:
# Losses:
# 		state_reconstruction_loss: 0.36316239833831787
# 		action_reconstruction_loss: 0.409492164850235
